# %% [markdown]
# # Jupyter notebook to visualize our results after training PyTorch model
#
# Please run this notebook from the notebooks directory.
#
# Some useful links:
# - https://brandonrozek.com/blog/jupyterwithpyenv/
#
# - https://github.com/microsoft/vscode-jupyter/wiki/Setting-Up-Run-by-Line-and-Debugging-for-Notebooks

# %%
# !python --version
# Out:
# Python 3.10.6

# %%
import sys

sys.path.append('../')
sys.path.append('../src')

# %%
import matplotlib.pyplot as plt
import numpy as np
import torch

from hydra import initialize, compose
from omegaconf import OmegaConf, DictConfig
from pathlib import Path
from src import *
from src.trainer import Trainer


with initialize(version_base=None, config_path="../config"):
    cfg = compose(config_name='trainer.yaml')

    cfg.wandb.mode = "disabled"
    ## Save dataset or load it
    # cfg.dataset.save_format = "pkl"  # to save dataset
    p = Path(cfg.dataset.filename)
    cfg.dataset.filename = f"../{str(p.parent)}/{p.stem}_dataset.pkl"
    # Comment the previous lines if don't want to save dataset or load it

    trainer = Trainer(cfg)

    ### Loading checkpoint
    general_checkpoint = torch.load("../checkpoints/last_general_checkpoint.pth")
    trainer.model.load_state_dict(general_checkpoint["model_state_dict"])
    trainer.optimizer.load_state_dict(general_checkpoint["optimizer_state_dict"])

    trainer.epoch = general_checkpoint["epoch"]
    torch.train_loss = general_checkpoint["train_loss"]
    torch.val_loss = general_checkpoint["val_loss"]
    
    trainer.model.eval()
    
    print(OmegaConf.to_yaml(cfg))
# Out:
# Failed to detect the name of this notebook, you can set it manually with the WANDB_NOTEBOOK_NAME environment variable to enable code saving.
# Config:
# wandb:
#   project: POLAR-background-prediction
#   mode: disabled
# wandb_watch: true
# common:
#   seed: 42
#   n_epochs: 200
#   device: cuda
# dataset:
#   filename: ../data/nf1rate_dataset.pkl
#   save_format: null
#   new_columns:
#   - rate[0]/rate_err[0]
#   feature_names:
#   - unix_time
#   - glat
#   - glon
#   - altitude
#   - temperature
#   - fe_cosmic
#   - raz
#   - decz
#   - rax
#   - decx
#   - is_orbit_up
#   - time_since_saa
#   - B_r
#   - B_theta
#   - B_phi
#   target_names:
#   - rate[0]/rate_err[0]
#   filter_conditions:
#   - rate[0]/rate_err[0] > 20
#   train:
#     size: 0.6
#     batch_size: 200
#     shuffle: true
#   val:
#     size: 0.2
#     batch_size: 200
#   test:
#     size: 0.2
#     batch_size: 200
# model:
#   type: MLP
#   inner_activation_fct: ReLU
#   output_activation_fct: null
#   hidden_layer_sizes:
#   - 100
#   - 100
# optimizer:
#   hyperparams:
#     lr: 0.001
#     betas:
#     - 0.9
#     - 0.999
#     eps: 1.0e-08
#
# Using device: cuda
# Using default identity activation function for last layer
# wandb:
#   project: POLAR-background-prediction
#   mode: disabled
# wandb_watch: true
# common:
#   seed: 42
#   n_epochs: 200
#   device: cuda
# dataset:
#   filename: ../data/nf1rate_dataset.pkl
#   save_format: null
#   new_columns:
#   - rate[0]/rate_err[0]
#   feature_names:
#   - unix_time
#   - glat
#   - glon
#   - altitude
#   - temperature
#   - fe_cosmic
#   - raz
#   - decz
#   - rax
#   - decx
#   - is_orbit_up
#   - time_since_saa
#   - B_r
#   - B_theta
#   - B_phi
#   target_names:
#   - rate[0]/rate_err[0]
#   filter_conditions:
#   - rate[0]/rate_err[0] > 20
#   train:
#     size: 0.6
#     batch_size: 200
#     shuffle: true
#   val:
#     size: 0.2
#     batch_size: 200
#   test:
#     size: 0.2
#     batch_size: 200
# model:
#   type: MLP
#   inner_activation_fct: ReLU
#   output_activation_fct: null
#   hidden_layer_sizes:
#   - 100
#   - 100
# optimizer:
#   hyperparams:
#     lr: 0.001
#     betas:
#     - 0.9
#     - 0.999
#     eps: 1.0e-08

# %%
trainer.dataset_full.data_df
# Out:
#             unix_time       glat        glon    altitude  temperature  \
# 0        1.483525e+09  41.273513   64.930544  376.565432    33.500000
# 1        1.483525e+09  41.301336   65.091966  376.553905    33.500000
# 2        1.483525e+09  41.301336   65.091966  376.553905    33.500000
# 3        1.483525e+09  41.328899   65.253475  376.536191    33.500000
# 4        1.483525e+09  41.328899   65.253475  376.536191    33.500000
# ...               ...        ...         ...         ...          ...
# 3956641  1.489745e+09 -42.757777  126.189354  386.590141    34.400002
# 3956642  1.489745e+09 -42.758912  126.358379  386.578593    34.400002
# 3956643  1.489745e+09 -42.758912  126.358379  386.578593    34.400002
# 3956644  1.489745e+09 -42.759779  126.527354  386.562382    34.400002
# 3956645  1.489745e+09 -42.759779  126.527354  386.562382    34.400002
#
#          fe_cosmic    corrected  correrr  config         raz  ...  \
# 0           1177.0  1111.225454      0.0      42  335.977594  ...
# 1           1185.0  1077.260702      0.0      42  336.125659  ...
# 2           1185.0  1067.501924      0.0      42  336.125659  ...
# 3           2154.0  1108.812904      0.0      42  336.273850  ...
# 4           2154.0  1110.524550      0.0      42  336.273850  ...
# ...            ...          ...      ...     ...         ...  ...
# 3956641    24460.0  1946.386405      0.0      42   91.466481  ...
# 3956642    24778.0  2020.254206      0.0      42   91.614903  ...
# 3956643    24778.0  1960.692600      0.0      42   91.614903  ...
# 3956644    24223.0  2001.103329      0.0      42   91.763169  ...
# 3956645    24223.0  2006.959229      0.0      42   91.763169  ...
#
#          rate_err[4]  rate_err[5]  rate_err[6]  rate_err[7]  rate_err[8]  \
# 0           2.567960    57.652239    52.385469    39.950259    26.693248
# 1           1.097337    58.313242    53.576569    42.127169    27.986472
# 2           2.536110    58.309515    53.611688    41.436761    27.814336
# 3           2.284171    58.768888    53.985650    41.722093    27.564099
# 4           1.408732    58.254816    53.523039    41.459358    28.045588
# ...              ...          ...          ...          ...          ...
# 3956641     3.133076    78.836820    71.228548    55.682940    38.233360
# 3956642     4.632954    79.408475    72.413146    56.606334    38.744268
# 3956643     3.101901    78.254113    71.264054    55.356600    37.391817
# 3956644     3.469219    77.563992    70.275058    55.193748    38.037999
# 3956645     4.774388    77.990096    70.800641    55.309920    37.370991
#
#          rate_err[9]  rate_err[10]  rate_err[11]  rate_err[12]  \
# 0          22.110430     62.045995     12.909292     60.913647
# 1          22.971606     62.461609     13.256035     62.418086
# 2          23.010703     62.985185     13.034515     62.923828
# 3          22.368073     63.693900     12.626513     63.606376
# 4          23.051952     63.082339     14.103237     63.008902
# ...              ...           ...           ...           ...
# 3956641    31.472766     86.974534     18.192699     86.974534
# 3956642    32.452418     87.649576     18.919566     87.649576
# 3956643    30.278941     86.726588     17.912328     86.721439
# 3956644    31.583499     86.736518     17.897704     86.723956
# 3956645    30.489693     86.770368     18.199318     86.770368
#
#          rate[0]/rate_err[0]
# 0                  28.621580
# 1                  27.929632
# 2                  27.636904
# 3                  28.166676
# 4                  28.515913
# ...                      ...
# 3956641            39.073977
# 3956642            40.109691
# 3956643            39.401131
# 3956644            39.691491
# 3956645            39.764508
#
# [3935518 rows x 48 columns]

# %%
## Prediction on WHOLE FULL set (e.g rate[0])
# Need to transform before inputting the whole data set into
# the model
dataset_full = trainer.dataset_full
dataset_full_tensor = dataset_full.X
dataset_full_tensor = dataset_full.transform(dataset_full_tensor)

pred = trainer.model(dataset_full_tensor)

data_df = dataset_full.data_df

# %%
from src.visualizer import plot_val_residual
from torch.utils.data import Subset

for target_name in cfg.dataset.target_names:
    # used plot_val but to plot whole dataset..
    plot_val_residual(Subset(dataset_full, range(dataset_full.data_df.shape[0])),
                      pred,
                      target_name=target_name,
                      save_path=None,
                      save_path_hist=None)
# Out:
# /usr/lib/python3/dist-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.17.3 and <1.25.0 is required for this version of SciPy (detected version 1.25.1
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# Index(['unix_time', 'glat', 'glon', 'altitude', 'temperature', 'fe_cosmic',
#        'raz', 'decz', 'rax', 'decx', 'is_orbit_up', 'time_since_saa', 'B_r',
#        'B_theta', 'B_phi'],
#       dtype='object')

# %%
from src.visualizer import get_time_y_y_hat, find_moments
tmp = get_time_y_y_hat(Subset(dataset_full, range(dataset_full.data_df.shape[0])),
                       pred,
                       target_name)
sorted_time_full, sorted_y_full, sorted_y_hat_full = tmp
del tmp

residuals = sorted_y_full-sorted_y_hat_full
new_mean, new_std = find_moments(residuals)
# Out:
# Index(['unix_time', 'glat', 'glon', 'altitude', 'temperature', 'fe_cosmic',
#        'raz', 'decz', 'rax', 'decx', 'is_orbit_up', 'time_since_saa', 'B_r',
#        'B_theta', 'B_phi'],
#       dtype='object')

# %%
np.sum(residuals.values > 5*new_std)
# Out:
# 37070

# %%
plt.plot(data_df["unix_time"], data_df["rate[0]/rate_err[0]"],
         linewidth=0.05, label="whole data")

plt.scatter(data_df.loc[residuals.values > 5*new_std, "unix_time"],
         data_df.loc[residuals.values > 5*new_std, "rate[0]/rate_err[0]"],
         color='r', label=r"Data s.t res > $5\sigma$")
plt.title(r"Residual > $5\sigma$")
plt.legend()
plt.show()
# Out:
# /home/zenchiyu/.local/lib/python3.10/site-packages/IPython/core/pylabtools.py:152: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)

# %% [markdown]
# ### GRBs

# %%
import pandas as pd

# %%
GRBs = pd.read_csv("../data/GRBs.csv")
GRBs
# Out:
#     Number       GRB_Name         Trigger_time_UTC     unix_time
# 0        1    GRB_160924A  2016-09-24T06:04:09.040  1.474697e+09
# 1        2    GRB_160928A  2016-09-28T19:48:05.000  1.475092e+09
# 2        3  GRB_161009651  2016-10-09T15:38:07.190  1.476027e+09
# 3        4  GRB_161011217  2016-10-11T05:13:44.420  1.476163e+09
# 4        5  GRB_161012989  2016-10-12T23:45:11.380  1.476316e+09
# 5        6  GRB_161013948  2016-10-13T22:44:40.100  1.476399e+09
# 6        7  GRB_161120401  2016-11-20T09:38:33.520  1.479635e+09
# 7        8    GRB_161129A  2016-11-29T07:11:40.000  1.480404e+09
# 8        9    GRB_161203A  2016-12-03T18:41:07.750  1.480790e+09
# 9       10    GRB_161205A  2016-12-05T13:27:18.000  1.480944e+09
# 10      11    GRB_161207A  2016-12-07T20:42:55.000  1.481143e+09
# 11      12    GRB_161207B  2016-12-07T05:22:44.000  1.481088e+09
# 12      13    GRB_161210A  2016-12-10T12:33:54.000  1.481373e+09
# 13      14    GRB_161212A  2016-12-12T15:38:59.000  1.481557e+09
# 14      15    GRB_161213A  2016-12-13T07:05:02.000  1.481613e+09
# 15      16    GRB_161217B  2016-12-17T03:03:44.000  1.481944e+09
# 16      17    GRB_161217C  2016-12-17T03:53:15.000  1.481947e+09
# 17      18    GRB_161218A  2016-12-18T03:47:34.634  1.482033e+09
# 18      19    GRB_161218B  2016-12-18T08:32:41.341  1.482050e+09
# 19      20    GRB_161219B  2016-12-19T18:48:39.000  1.482173e+09
# 20      21    GRB_161228A  2016-12-28T09:43:24.000  1.482918e+09
# 21      22    GRB_161228B  2016-12-28T13:15:40.000  1.482931e+09
# 22      23    GRB_161228C  2016-12-28T00:46:20.000  1.482886e+09
# 23      24    GRB_161229A  2016-12-29T21:03:49.000  1.483045e+09
# 24      25    GRB_161230A  2016-12-30T12:16:07.000  1.483100e+09
# 25      26    GRB_170101A  2017-01-01T02:26:00.660  1.483238e+09
# 26      27    GRB_170101B  2017-01-01T02:47:18.270  1.483239e+09
# 27      28    GRB_170102A  2017-01-02T02:51:18.000  1.483325e+09
# 28      29    GRB_170105A  2017-01-05T06:14:07.000  1.483597e+09
# 29      30    GRB_170109A  2017-01-09T03:17:35.000  1.483932e+09
# 30      31    GRB_170112B  2017-01-12T23:16:09.000  1.484263e+09
# 31      32    GRB_170114A  2017-01-14T22:01:10.000  1.484431e+09
# 32      33    GRB_170114B  2017-01-14T19:59:12.000  1.484424e+09
# 33      34    GRB_170120A  2017-01-20T11:18:30.000  1.484911e+09
# 34      35    GRB_170121A  2017-01-21T01:36:55.200  1.484963e+09
# 35      36    GRB_170124A  2017-01-24T20:58:06.000  1.485291e+09
# 36      37    GRB_170127C  2017-01-27T01:35:49.000  1.485481e+09
# 37      38    GRB_170130A  2017-01-30T07:14:45.000  1.485760e+09
# 38      39    GRB_170131A  2017-01-31T23:14:59.000  1.485904e+09
# 39      40    GRB_170202B  2017-02-02T07:19:54.000  1.486020e+09
# 40      41    GRB_170206A  2017-02-06T10:51:57.700  1.486378e+09
# 41      42    GRB_170206C  2017-02-06T11:40:10.000  1.486381e+09
# 42      43    GRB_170207A  2017-02-07T21:45:04.000  1.486504e+09
# 43      44    GRB_170208C  2017-02-08T13:16:33.000  1.486560e+09
# 44      45    GRB_170210A  2017-02-10T02:47:37.000  1.486695e+09
# 45      46    GRB_170219A  2017-02-19T00:03:07.000  1.487463e+09
# 46      47    GRB_170220A  2017-02-20T18:48:01.000  1.487616e+09
# 47      48    GRB_170228B  2017-02-28T18:32:56.000  1.488307e+09
# 48      49    GRB_170305A  2017-03-05T06:09:06.800  1.488694e+09
# 49      50    GRB_170306B  2017-03-06T14:07:20.000  1.488809e+09
# 50      51    GRB_170309A  2017-03-09T12:26:42.000  1.489062e+09
# 51      52    GRB_170315A  2017-03-15T13:57:53.000  1.489586e+09
# 52      53    GRB_170317A  2017-03-17T09:45:56.000  1.489744e+09
# 53      54    GRB_170320A  2017-03-20T03:42:39.000  1.489981e+09
# 54      55    GRB_170325B  2017-03-25T21:50:01.000  1.490479e+09

# %%
plt.plot(data_df["unix_time"], data_df["rate[0]/rate_err[0]"], linewidth=0.05)
plt.scatter(GRBs["unix_time"], np.zeros_like(GRBs["unix_time"]), color="r")
plt.title("55 GRBs against full dataset")
# Out:
# Text(0.5, 1.0, '55 GRBs against full dataset')

# %% [markdown]
# Let's only take a look at the GRBs happening within the same time range

# %%
mask = data_df["unix_time"].min() <= GRBs["unix_time"].values
mask &= GRBs["unix_time"].values <= data_df["unix_time"].max()
print(f"Out of 55, there are: {mask.sum()} GRBs within our time range")
# Out:
# Out of 55, there are: 25 GRBs within our time range

# %%
plt.plot(data_df["unix_time"], data_df["rate[0]/rate_err[0]"], linewidth=0.05)
plt.scatter(GRBs["unix_time"][mask], np.zeros_like(GRBs["unix_time"][mask]), color="r")
plt.show()

# %% [markdown]
# Zooming into the GRBs with a window of 100 seconds before and 100 seconds after

# %%
w = 100

fig, axs = plt.subplots(5, 5, figsize=(10, 12), sharey=True)

for i, GRB_name, GRB_tunix in zip(range(mask.sum()),
                        GRBs["GRB_Name"][mask],
                        GRBs["unix_time"][mask]):
    m = data_df["unix_time"] >= GRB_tunix-w
    m &= data_df["unix_time"] <= GRB_tunix+w
    axs[i//5, i%5].plot(data_df[m]["unix_time"],
             data_df[m]["rate[0]/rate_err[0]"], linewidth=0.4)
    axs[i//5, i%5].vlines(GRB_tunix, 0,
                          data_df[m]["rate[0]/rate_err[0]"].max(),
                          'r', linewidth=0.1)
    axs[i//5, i%5].set_title(GRB_name)
plt.tight_layout()
# Out:
# /usr/lib/python3/dist-packages/matplotlib/axes/_base.py:2475: UserWarning: Warning: converting a masked element to nan.
#   xys = np.asarray(xys)

# %% [markdown]
# Comparing with where our algo fails

# %%
fig, axs = plt.subplots(5, 5, figsize=(10, 12), sharey=True)

for i, GRB_name, GRB_tunix in zip(range(mask.sum()),
                        GRBs["GRB_Name"][mask],
                        GRBs["unix_time"][mask]):
    m = data_df["unix_time"] >= GRB_tunix-w
    m &= data_df["unix_time"] <= GRB_tunix+w
    mpred = m & (residuals.values > 3.5*new_std)

    axs[i//5, i%5].plot(data_df[m]["unix_time"],
             data_df[m]["rate[0]/rate_err[0]"], linewidth=0.4)
    axs[i//5, i%5].vlines(GRB_tunix, 0,
                          data_df[m]["rate[0]/rate_err[0]"].max(),
                          'r', linewidth=0.1)
    axs[i//5, i%5].set_title(GRB_name)

    # Based on our residuals
    axs[i//5, i%5].scatter(data_df.loc[mpred, "unix_time"],
         data_df.loc[mpred, "rate[0]/rate_err[0]"],
         color='r', label=r"data s.t res > $3.5\sigma$")
plt.tight_layout()
# Out:
# /usr/lib/python3/dist-packages/matplotlib/axes/_base.py:2475: UserWarning: Warning: converting a masked element to nan.
#   xys = np.asarray(xys)
